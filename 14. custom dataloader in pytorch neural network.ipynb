# %% [markdown]
# # Custom DataSet components
# - Dataset `torch.utils.data.Dataset`
# - DataLoader `torch.utils.data.DataLoader`

# %% [markdown]
# # Dataset has
# - __init__() for initialize the data object, load data
# - __len__() for return the total length of samples
# - __getitem__() for returning a element from dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mirichoi0218/insurance")
# Out:
# Using Colab cache for faster access to the 'insurance' dataset.

# %%
# importing essential module
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(path + '/insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Split data into train and test set
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# %%
# Encoding the categorical features
label_encoder = {}

for col in ['sex', 'smoker', 'region']:
  le = LabelEncoder()
  train_df[col] = le.fit_transform(train_df[col])
  test_df[col] = le.transform(test_df[col])
  label_encoder[col] = le

# %%
# Featured and targeting
X_train = train_df.drop(columns='charges')
y_train = train_df['charges']

X_test = test_df.drop(columns='charges')
y_test = test_df['charges']

# %%
# Normalize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Convert numpy to tensor
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32).view((-1, 1))

# %% [markdown]
# # Create a custom Dataset and DataLoader

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %%
# Custom Dataset
class InsuranceData(Dataset):
  def __init__(self, X, y):
    self.X = X
    self.y = y

  def __len__(self):
    return len(self.X)

  def __getitem__(self, indx):
    features = torch.tensor(self.X[indx], dtype=torch.float32)
    target = torch.tensor(self.y.values[indx], dtype=torch.float32).view(1)

    return features, target

# %%
# Dataset instance
insurance = InsuranceData(X_train, y_train)

# %%
# DataLoader
dataloader = DataLoader(insurance, batch_size=50, shuffle=True)

# # For checking
# for i, j in dataloader:
#   print(i.shape, j.shape)

# %% [markdown]
# # Create Model and train

# %%
class SimpleNNReg(nn.Module):
  def __init__(self, input_size):
    super(SimpleNNReg, self).__init__()

    self.network = nn.Sequential(
        nn.Linear(input_size, 64),
        nn.ReLU(),
        nn.Linear(64, 128),
        nn.ReLU(),
        nn.Linear(128, 1)
    )

  def forward(self, x):
    return self.network(x)

# %%
# Create model instance
in_sz = 6
model = SimpleNNReg(in_sz)
model
# Out:
# SimpleNNReg(
#   (network): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
# Loss function and optimizer
loss_fun = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
# Training loop
epochs = 5000

for e in range(epochs):
  model.train() # For train mode
  for batch, (x_tensor, y_tensor) in enumerate(dataloader):
    optimizer.zero_grad()
    outputs = model(x_tensor)

    loss = loss_fun(outputs, y_tensor)
    loss.backward()
    optimizer.step()
    print(f'--> batch [{batch + 1}], loss = {loss.item():0.4f}')

  if (e + 1) % 100 == 0:
    print(f'Epoch [{e + 1}/{epochs}], loss = {loss.item():0.4f}')
# Out:
# Streaming output truncated to the last 5000 lines.
# --> batch [20], loss = 12863479.0000
# --> batch [21], loss = 6177952.0000
# --> batch [22], loss = 8205086.5000
# --> batch [1], loss = 8968028.0000
# --> batch [2], loss = 4155403.0000
# --> batch [3], loss = 7750973.5000
# --> batch [4], loss = 2852914.0000
# --> batch [5], loss = 12577306.0000
# --> batch [6], loss = 11076983.0000
# --> batch [7], loss = 13173992.0000
# --> batch [8], loss = 10134867.0000
# --> batch [9], loss = 5477068.0000
# --> batch [10], loss = 10236419.0000
# --> batch [11], loss = 4316387.0000
# --> batch [12], loss = 6336782.5000
# --> batch [13], loss = 7650898.0000
# --> batch [14], loss = 10074815.0000
# --> batch [15], loss = 12746090.0000
# --> batch [16], loss = 10996419.0000
# --> batch [17], loss = 6207789.5000
# --> batch [18], loss = 11365037.0000
# --> batch [19], loss = 9292947.0000
# --> batch [20], loss = 6730351.5000
# --> batch [21], loss = 6310391.5000
# --> batch [22], loss = 10148958.0000
# --> batch [1], loss = 6767605.0000
# --> batch [2], loss = 9906806.0000
# --> batch [3], loss = 9990314.0000
# --> batch [4], loss = 11268503.0000
# --> batch [5], loss = 3515691.7500
# --> batch [6], loss = 10880998.0000
# --> batch [7], loss = 9007322.0000
# --> batch [8], loss = 4578850.0000
# --> batch [9], loss = 15520443.0000
# --> batch [10], loss = 7099259.0000
# --> batch [11], loss = 9228115.0000
# --> batch [12], loss = 12572570.0000
# --> batch [13], loss = 8873537.0000
# --> batch [14], loss = 5595265.5000
# --> batch [15], loss = 4574302.0000
# --> batch [16], loss = 9704710.0000
# --> batch [17], loss = 9691535.0000
# --> batch [18], loss = 3601291.0000
# --> batch [19], loss = 7268957.0000
# --> batch [20], loss = 11822639.0000
# --> batch [21], loss = 6211337.0000
# --> batch [22], loss = 16114782.0000
# --> batch [1], loss = 10529608.0000
# --> batch [2], loss = 11086259.0000
# --> batch [3], loss = 10769505.0000
# --> batch [4], loss = 8066414.5000
# --> batch [5], loss = 4021841.2500
# --> batch [6], loss = 8987249.0000
# --> batch [7], loss = 8678850.0000
# --> batch [8], loss = 11582345.0000
# --> batch [9], loss = 7711466.0000
# --> batch [10], loss = 7022558.0000
# --> batch [11], loss = 10506859.0000
# --> batch [12], loss = 6695989.0000
# --> batch [13], loss = 8978253.0000
# --> batch [14], loss = 7150635.5000
# --> batch [15], loss = 10518589.0000
# --> batch [16], loss = 10635434.0000
# --> batch [17], loss = 11753618.0000
# --> batch [18], loss = 3763166.5000
# --> batch [19], loss = 4112091.2500
# --> batch [20], loss = 6736677.0000
# --> batch [21], loss = 9712835.0000
# --> batch [22], loss = 13993139.0000
# --> batch [1], loss = 10196381.0000
# --> batch [2], loss = 9819633.0000
# --> batch [3], loss = 8125964.0000
# --> batch [4], loss = 10731147.0000
# --> batch [5], loss = 6717944.5000
# --> batch [6], loss = 6454646.0000
# --> batch [7], loss = 8781033.0000
# --> batch [8], loss = 8232479.5000
# --> batch [9], loss = 10252536.0000
# --> batch [10], loss = 13724046.0000
# --> batch [11], loss = 5596610.0000
# --> batch [12], loss = 9566766.0000
# --> batch [13], loss = 12294042.0000
# --> batch [14], loss = 7482533.0000
# --> batch [15], loss = 13081179.0000
# --> batch [16], loss = 6954907.5000
# --> batch [17], loss = 6352377.0000
# --> batch [18], loss = 13073856.0000
# --> batch [19], loss = 8146131.0000
# --> batch [20], loss = 6327930.0000
# --> batch [21], loss = 6058901.0000
# --> batch [22], loss = 13078694.0000
# --> batch [1], loss = 9737618.0000
# --> batch [2], loss = 6360534.0000
# --> batch [3], loss = 5948028.0000
# --> batch [4], loss = 3295838.7500
# --> batch [5], loss = 11440575.0000
# --> batch [6], loss = 9941732.0000
# --> batch [7], loss = 3181794.0000
# --> batch [8], loss = 10311240.0000
# --> batch [9], loss = 6017323.0000
# --> batch [10], loss = 5701375.5000
# --> batch [11], loss = 6350598.5000
# --> batch [12], loss = 10649375.0000
# --> batch [13], loss = 10377948.0000
# --> batch [14], loss = 13860360.0000
# --> batch [15], loss = 9287992.0000
# --> batch [16], loss = 5743508.5000
# --> batch [17], loss = 5225561.5000
# --> batch [18], loss = 5913054.0000
# --> batch [19], loss = 9803160.0000
# --> batch [20], loss = 14163690.0000
# --> batch [21], loss = 10909622.0000
# --> batch [22], loss = 14619797.0000
# --> batch [1], loss = 3512373.7500
# --> batch [2], loss = 4760816.0000
# --> batch [3], loss = 7439058.0000
# --> batch [4], loss = 10182299.0000
# --> batch [5], loss = 6751236.5000
# --> batch [6], loss = 4286161.5000
# --> batch [7], loss = 10493270.0000
# --> batch [8], loss = 7465513.5000
# --> batch [9], loss = 10697833.0000
# --> batch [10], loss = 10014632.0000
# --> batch [11], loss = 7819360.0000
# --> batch [12], loss = 5060603.0000
# --> batch [13], loss = 12088659.0000
# --> batch [14], loss = 12322954.0000
# --> batch [15], loss = 4324764.0000
# --> batch [16], loss = 4983041.5000
# --> batch [17], loss = 3763172.2500
# --> batch [18], loss = 4441490.5000
# --> batch [19], loss = 24158134.0000
# --> batch [20], loss = 9991975.0000
# --> batch [21], loss = 12287391.0000
# --> batch [22], loss = 10698402.0000
# --> batch [1], loss = 9496568.0000
# --> batch [2], loss = 6203260.0000
# --> batch [3], loss = 7459294.0000
# --> batch [4], loss = 12055766.0000
# --> batch [5], loss = 4048819.2500
# --> batch [6], loss = 6535564.0000
# --> batch [7], loss = 9307624.0000
# --> batch [8], loss = 7861595.0000
# --> batch [9], loss = 11555535.0000
# --> batch [10], loss = 10046227.0000
# --> batch [11], loss = 5819096.5000
# --> batch [12], loss = 12080466.0000
# --> batch [13], loss = 4224559.0000
# --> batch [14], loss = 8836152.0000
# --> batch [15], loss = 9788884.0000
# --> batch [16], loss = 7441902.5000
# --> batch [17], loss = 10574556.0000
# --> batch [18], loss = 5190525.5000
# --> batch [19], loss = 6472994.0000
# --> batch [20], loss = 7328273.5000
# --> batch [21], loss = 11839153.0000
# --> batch [22], loss = 5042904.5000
# --> batch [1], loss = 6954595.0000
# --> batch [2], loss = 7365469.5000
# --> batch [3], loss = 9864312.0000
# --> batch [4], loss = 8308286.0000
# --> batch [5], loss = 12039724.0000
# --> batch [6], loss = 8591299.0000
# --> batch [7], loss = 14196340.0000
# --> batch [8], loss = 7262432.0000
# --> batch [9], loss = 4457561.0000
# --> batch [10], loss = 7339734.5000
# --> batch [11], loss = 7521645.5000
# --> batch [12], loss = 10979640.0000
# --> batch [13], loss = 10835195.0000
# --> batch [14], loss = 7638521.0000
# --> batch [15], loss = 9314499.0000
# --> batch [16], loss = 6635302.5000
# --> batch [17], loss = 7774243.0000
# --> batch [18], loss = 5547017.0000
# --> batch [19], loss = 1935848.5000
# --> batch [20], loss = 8473308.0000
# --> batch [21], loss = 10557480.0000
# --> batch [22], loss = 13628994.0000
# --> batch [1], loss = 6073539.0000
# --> batch [2], loss = 7235275.5000
# --> batch [3], loss = 11149558.0000
# --> batch [4], loss = 5729915.0000
# --> batch [5], loss = 11128358.0000
# --> batch [6], loss = 12040863.0000
# --> batch [7], loss = 5202952.5000
# --> batch [8], loss = 16357176.0000
# --> batch [9], loss = 6901348.0000
# --> batch [10], loss = 12221507.0000
# --> batch [11], loss = 4475652.0000
# --> batch [12], loss = 8152749.5000
# --> batch [13], loss = 5891961.5000
# --> batch [14], loss = 5391156.0000
# --> batch [15], loss = 9920443.0000
# --> batch [16], loss = 6711914.0000
# --> batch [17], loss = 7975420.0000
# --> batch [18], loss = 6568825.5000
# --> batch [19], loss = 13072372.0000
# --> batch [20], loss = 12558976.0000
# --> batch [21], loss = 3976918.7500
# --> batch [22], loss = 10241846.0000
# --> batch [1], loss = 14231762.0000
# --> batch [2], loss = 14388328.0000
# --> batch [3], loss = 5018021.0000
# --> batch [4], loss = 16803998.0000
# --> batch [5], loss = 8480084.0000
# --> batch [6], loss = 5649652.5000
# --> batch [7], loss = 11258817.0000
# --> batch [8], loss = 8794980.0000
# --> batch [9], loss = 9930648.0000
# --> batch [10], loss = 7538110.5000
# --> batch [11], loss = 11579496.0000
# --> batch [12], loss = 5731401.0000
# --> batch [13], loss = 14634330.0000
# --> batch [14], loss = 8914760.0000
# --> batch [15], loss = 4876526.0000
# --> batch [16], loss = 7961605.0000
# --> batch [17], loss = 5255359.5000
# --> batch [18], loss = 6808476.0000
# --> batch [19], loss = 9937554.0000
# --> batch [20], loss = 4702166.5000
# --> batch [21], loss = 6400157.5000
# --> batch [22], loss = 5604009.0000
# --> batch [1], loss = 8178800.5000
# --> batch [2], loss = 8580139.0000
# --> batch [3], loss = 18003560.0000
# --> batch [4], loss = 4511325.5000
# --> batch [5], loss = 10243752.0000
# --> batch [6], loss = 6358622.5000
# --> batch [7], loss = 9366687.0000
# --> batch [8], loss = 9215861.0000
# --> batch [9], loss = 8537408.0000
# --> batch [10], loss = 7100737.5000
# --> batch [11], loss = 9326742.0000
# --> batch [12], loss = 5004147.5000
# --> batch [13], loss = 7395735.5000
# --> batch [14], loss = 6332612.5000
# --> batch [15], loss = 9483516.0000
# --> batch [16], loss = 7528992.0000
# --> batch [17], loss = 11733542.0000
# --> batch [18], loss = 7628137.5000
# --> batch [19], loss = 7880366.0000
# --> batch [20], loss = 10577885.0000
# --> batch [21], loss = 14554266.0000
# --> batch [22], loss = 4225083.0000
# --> batch [1], loss = 8084242.5000
# --> batch [2], loss = 6113628.0000
# --> batch [3], loss = 5922771.0000
# --> batch [4], loss = 13391148.0000
# --> batch [5], loss = 7835397.0000
# --> batch [6], loss = 5048282.5000
# --> batch [7], loss = 7721651.0000
# --> batch [8], loss = 5426446.5000
# --> batch [9], loss = 11528888.0000
# --> batch [10], loss = 7213649.5000
# --> batch [11], loss = 8439540.0000
# --> batch [12], loss = 11714127.0000
# --> batch [13], loss = 9475608.0000
# --> batch [14], loss = 4076398.5000
# --> batch [15], loss = 1906117.7500
# --> batch [16], loss = 18906882.0000
# --> batch [17], loss = 8154503.5000
# --> batch [18], loss = 17600948.0000
# --> batch [19], loss = 4802424.5000
# --> batch [20], loss = 6633392.5000
# --> batch [21], loss = 8846270.0000
# --> batch [22], loss = 9871022.0000
# --> batch [1], loss = 15372495.0000
# --> batch [2], loss = 4975014.5000
# --> batch [3], loss = 8150095.5000
# --> batch [4], loss = 9228948.0000
# --> batch [5], loss = 9564288.0000
# --> batch [6], loss = 8851108.0000
# --> batch [7], loss = 9012314.0000
# --> batch [8], loss = 4322886.5000
# --> batch [9], loss = 14433320.0000
# --> batch [10], loss = 8403717.0000
# --> batch [11], loss = 12919820.0000
# --> batch [12], loss = 4300964.0000
# --> batch [13], loss = 11847224.0000
# --> batch [14], loss = 7999701.0000
# --> batch [15], loss = 5195302.5000
# --> batch [16], loss = 6866318.5000
# --> batch [17], loss = 7028217.5000
# --> batch [18], loss = 2166827.0000
# --> batch [19], loss = 12295421.0000
# --> batch [20], loss = 6024646.5000
# --> batch [21], loss = 13181606.0000
# --> batch [22], loss = 10614854.0000
# --> batch [1], loss = 7177483.5000
# --> batch [2], loss = 11737076.0000
# --> batch [3], loss = 6294719.5000
# --> batch [4], loss = 3783776.2500
# --> batch [5], loss = 11992805.0000
# --> batch [6], loss = 4986062.5000
# --> batch [7], loss = 9391002.0000
# --> batch [8], loss = 4636424.0000
# --> batch [9], loss = 6047876.0000
# --> batch [10], loss = 6978681.5000
# --> batch [11], loss = 8354798.0000
# --> batch [12], loss = 12840137.0000
# --> batch [13], loss = 12841912.0000
# --> batch [14], loss = 6939431.0000
# --> batch [15], loss = 14217679.0000
# --> batch [16], loss = 11146497.0000
# --> batch [17], loss = 7949602.0000
# --> batch [18], loss = 5787697.5000
# --> batch [19], loss = 9942313.0000
# --> batch [20], loss = 16121299.0000
# --> batch [21], loss = 4235777.5000
# --> batch [22], loss = 8415349.0000
# --> batch [1], loss = 9729981.0000
# --> batch [2], loss = 4866592.0000
# --> batch [3], loss = 6141685.0000
# --> batch [4], loss = 7297084.0000
# --> batch [5], loss = 6707672.5000
# --> batch [6], loss = 12164948.0000
# --> batch [7], loss = 4429838.5000
# --> batch [8], loss = 6326537.0000
# --> batch [9], loss = 7085909.0000
# --> batch [10], loss = 11662049.0000
# --> batch [11], loss = 11217339.0000
# --> batch [12], loss = 7737852.0000
# --> batch [13], loss = 7630402.5000
# --> batch [14], loss = 9284624.0000
# --> batch [15], loss = 7046093.0000
# --> batch [16], loss = 14404078.0000
# --> batch [17], loss = 11649423.0000
# --> batch [18], loss = 7120958.5000
# --> batch [19], loss = 4509925.0000
# --> batch [20], loss = 15093627.0000
# --> batch [21], loss = 5596388.0000
# --> batch [22], loss = 17654358.0000
# --> batch [1], loss = 11303921.0000
# --> batch [2], loss = 7624418.5000
# --> batch [3], loss = 3620391.0000
# --> batch [4], loss = 11620134.0000
# --> batch [5], loss = 10106515.0000
# --> batch [6], loss = 5208694.0000
# --> batch [7], loss = 9304226.0000
# --> batch [8], loss = 6365470.5000
# --> batch [9], loss = 9123900.0000
# --> batch [10], loss = 6553030.5000
# --> batch [11], loss = 9950408.0000
# --> batch [12], loss = 5564884.5000
# --> batch [13], loss = 6389634.5000
# --> batch [14], loss = 4174274.5000
# --> batch [15], loss = 11165345.0000
# --> batch [16], loss = 5028074.5000
# --> batch [17], loss = 13560287.0000
# --> batch [18], loss = 4722214.0000
# --> batch [19], loss = 13765966.0000
# --> batch [20], loss = 8833555.0000
# --> batch [21], loss = 13253010.0000
# --> batch [22], loss = 18238956.0000
# --> batch [1], loss = 7475255.5000
# --> batch [2], loss = 11175496.0000
# --> batch [3], loss = 15413002.0000
# --> batch [4], loss = 10204824.0000
# --> batch [5], loss = 4437314.0000
# --> batch [6], loss = 12184594.0000
# --> batch [7], loss = 10018084.0000
# --> batch [8], loss = 5474754.0000
# --> batch [9], loss = 7780552.5000
# --> batch [10], loss = 6354535.5000
# --> batch [11], loss = 8563968.0000
# --> batch [12], loss = 13134167.0000
# --> batch [13], loss = 12108157.0000
# --> batch [14], loss = 5490611.0000
# --> batch [15], loss = 7786782.5000
# --> batch [16], loss = 10809925.0000
# --> batch [17], loss = 3691893.5000
# --> batch [18], loss = 7805780.0000
# --> batch [19], loss = 5518566.5000
# --> batch [20], loss = 11278508.0000
# --> batch [21], loss = 9185330.0000
# --> batch [22], loss = 3610020.7500
# --> batch [1], loss = 11638794.0000
# --> batch [2], loss = 5474398.5000
# --> batch [3], loss = 6784036.5000
# --> batch [4], loss = 9591167.0000
# --> batch [5], loss = 3544451.2500
# --> batch [6], loss = 5901565.5000
# --> batch [7], loss = 11400938.0000
# --> batch [8], loss = 16810088.0000
# --> batch [9], loss = 5076094.0000
# --> batch [10], loss = 6955740.0000
# --> batch [11], loss = 4752260.5000
# --> batch [12], loss = 21646804.0000
# --> batch [13], loss = 6184052.0000
# --> batch [14], loss = 7596896.0000
# --> batch [15], loss = 8114201.5000
# --> batch [16], loss = 9526269.0000
# --> batch [17], loss = 7299277.5000
# --> batch [18], loss = 10885119.0000
# --> batch [19], loss = 7200936.5000
# --> batch [20], loss = 7163979.5000
# --> batch [21], loss = 8146610.5000
# --> batch [22], loss = 4481302.0000
# --> batch [1], loss = 9984580.0000
# --> batch [2], loss = 10344459.0000
# --> batch [3], loss = 5350422.0000
# --> batch [4], loss = 12751489.0000
# --> batch [5], loss = 9623415.0000
# --> batch [6], loss = 4777622.5000
# --> batch [7], loss = 11436128.0000
# --> batch [8], loss = 9861464.0000
# --> batch [9], loss = 8730419.0000
# --> batch [10], loss = 7794879.5000
# --> batch [11], loss = 9090994.0000
# --> batch [12], loss = 8441394.0000
# --> batch [13], loss = 12825106.0000
# --> batch [14], loss = 4646750.0000
# --> batch [15], loss = 7973094.5000
# --> batch [16], loss = 9085425.0000
# --> batch [17], loss = 5330559.0000
# --> batch [18], loss = 14293597.0000
# --> batch [19], loss = 5436624.5000
# --> batch [20], loss = 2938432.2500
# --> batch [21], loss = 8870472.0000
# --> batch [22], loss = 14875835.0000
# --> batch [1], loss = 8195348.0000
# --> batch [2], loss = 5357497.0000
# --> batch [3], loss = 14235860.0000
# --> batch [4], loss = 14491590.0000
# --> batch [5], loss = 7818379.5000
# --> batch [6], loss = 6343655.5000
# --> batch [7], loss = 5434550.5000
# --> batch [8], loss = 5559633.5000
# --> batch [9], loss = 10241376.0000
# --> batch [10], loss = 8794392.0000
# --> batch [11], loss = 11250588.0000
# --> batch [12], loss = 12817961.0000
# --> batch [13], loss = 5238184.5000
# --> batch [14], loss = 8593178.0000
# --> batch [15], loss = 7655279.5000
# --> batch [16], loss = 9606503.0000
# --> batch [17], loss = 14846264.0000
# --> batch [18], loss = 15966548.0000
# --> batch [19], loss = 8126066.0000
# --> batch [20], loss = 9239983.0000
# --> batch [21], loss = 7039457.5000
# --> batch [22], loss = 7438241.5000
# --> batch [1], loss = 3052925.5000
# --> batch [2], loss = 5707411.0000
# --> batch [3], loss = 5657523.0000
# --> batch [4], loss = 10484753.0000
# --> batch [5], loss = 10951767.0000
# --> batch [6], loss = 6854148.0000
# --> batch [7], loss = 10404675.0000
# --> batch [8], loss = 12220037.0000
# --> batch [9], loss = 10384767.0000
# --> batch [10], loss = 11806660.0000
# --> batch [11], loss = 7406558.5000
# --> batch [12], loss = 7834363.0000
# --> batch [13], loss = 6503937.5000
# --> batch [14], loss = 8178118.5000
# --> batch [15], loss = 6724056.5000
# --> batch [16], loss = 7578982.0000
# --> batch [17], loss = 6482246.5000
# --> batch [18], loss = 12777892.0000
# --> batch [19], loss = 16554870.0000
# --> batch [20], loss = 10645432.0000
# --> batch [21], loss = 3199943.7500
# --> batch [22], loss = 11302382.0000
# --> batch [1], loss = 7730581.0000
# --> batch [2], loss = 13760348.0000
# --> batch [3], loss = 9069616.0000
# --> batch [4], loss = 6685243.0000
# --> batch [5], loss = 21866248.0000
# --> batch [6], loss = 10064559.0000
# --> batch [7], loss = 8064244.5000
# --> batch [8], loss = 10783722.0000
# --> batch [9], loss = 5464919.5000
# --> batch [10], loss = 6346960.0000
# --> batch [11], loss = 3349775.2500
# --> batch [12], loss = 9147077.0000
# --> batch [13], loss = 9027212.0000
# --> batch [14], loss = 5478191.5000
# --> batch [15], loss = 7251897.5000
# --> batch [16], loss = 4026220.5000
# --> batch [17], loss = 10759145.0000
# --> batch [18], loss = 7452797.0000
# --> batch [19], loss = 4558743.5000
# --> batch [20], loss = 4523083.5000
# --> batch [21], loss = 10470282.0000
# --> batch [22], loss = 15931802.0000
# --> batch [1], loss = 6004782.0000
# --> batch [2], loss = 6359830.5000
# --> batch [3], loss = 15579557.0000
# --> batch [4], loss = 6785417.5000
# --> batch [5], loss = 9577206.0000
# --> batch [6], loss = 14984335.0000
# --> batch [7], loss = 7954004.5000
# --> batch [8], loss = 6187817.5000
# --> batch [9], loss = 7216962.0000
# --> batch [10], loss = 7304555.5000
# --> batch [11], loss = 5528658.0000
# --> batch [12], loss = 8559238.0000
# --> batch [13], loss = 10341871.0000
# --> batch [14], loss = 4060947.2500
# --> batch [15], loss = 17340482.0000
# --> batch [16], loss = 4607675.0000
# --> batch [17], loss = 12575534.0000
# --> batch [18], loss = 9308173.0000
# --> batch [19], loss = 7996909.0000
# --> batch [20], loss = 7257154.5000
# --> batch [21], loss = 3653844.5000
# --> batch [22], loss = 5029475.0000
# --> batch [1], loss = 4726421.5000
# --> batch [2], loss = 9845886.0000
# --> batch [3], loss = 4003933.5000
# --> batch [4], loss = 6238422.0000
# --> batch [5], loss = 7396006.5000
# --> batch [6], loss = 8085605.0000
# --> batch [7], loss = 2487136.7500
# --> batch [8], loss = 4094246.5000
# --> batch [9], loss = 7053010.0000
# --> batch [10], loss = 11910282.0000
# --> batch [11], loss = 9208986.0000
# --> batch [12], loss = 9251638.0000
# --> batch [13], loss = 7729321.5000
# --> batch [14], loss = 9672650.0000
# --> batch [15], loss = 7387954.5000
# --> batch [16], loss = 7766698.0000
# --> batch [17], loss = 7711282.5000
# --> batch [18], loss = 13433677.0000
# --> batch [19], loss = 17555080.0000
# --> batch [20], loss = 10867378.0000
# --> batch [21], loss = 11238666.0000
# --> batch [22], loss = 8984074.0000
# --> batch [1], loss = 12278591.0000
# --> batch [2], loss = 7374550.0000
# --> batch [3], loss = 8599865.0000
# --> batch [4], loss = 7601871.5000
# --> batch [5], loss = 4884430.0000
# --> batch [6], loss = 11991439.0000
# --> batch [7], loss = 9127649.0000
# --> batch [8], loss = 15962796.0000
# --> batch [9], loss = 3515818.2500
# --> batch [10], loss = 4781292.0000
# --> batch [11], loss = 15553437.0000
# --> batch [12], loss = 11338601.0000
# --> batch [13], loss = 5993958.5000
# --> batch [14], loss = 8107790.0000
# --> batch [15], loss = 9718825.0000
# --> batch [16], loss = 11426249.0000
# --> batch [17], loss = 8486529.0000
# --> batch [18], loss = 7697584.5000
# --> batch [19], loss = 6810105.5000
# --> batch [20], loss = 5152637.0000
# --> batch [21], loss = 10409148.0000
# --> batch [22], loss = 6163310.0000
# --> batch [1], loss = 5717295.5000
# --> batch [2], loss = 13235827.0000
# --> batch [3], loss = 2642089.7500
# --> batch [4], loss = 5760486.5000
# --> batch [5], loss = 8156640.0000
# --> batch [6], loss = 4766406.0000
# --> batch [7], loss = 11619766.0000
# --> batch [8], loss = 12137431.0000
# --> batch [9], loss = 14313517.0000
# --> batch [10], loss = 7597497.5000
# --> batch [11], loss = 10443310.0000
# --> batch [12], loss = 8131068.0000
# --> batch [13], loss = 5215392.5000
# --> batch [14], loss = 9974929.0000
# --> batch [15], loss = 10819923.0000
# --> batch [16], loss = 11100950.0000
# --> batch [17], loss = 4025215.7500
# --> batch [18], loss = 5246909.0000
# --> batch [19], loss = 14262917.0000
# --> batch [20], loss = 11150902.0000
# --> batch [21], loss = 12949907.0000
# --> batch [22], loss = 3557799.2500
# --> batch [1], loss = 6029988.0000
# --> batch [2], loss = 4654099.0000
# --> batch [3], loss = 6289784.5000
# --> batch [4], loss = 5972713.5000
# --> batch [5], loss = 4573614.5000
# --> batch [6], loss = 13826364.0000
# --> batch [7], loss = 7647275.5000
# --> batch [8], loss = 8130087.0000
# --> batch [9], loss = 7166503.5000
# --> batch [10], loss = 6830255.5000
# --> batch [11], loss = 13445263.0000
# --> batch [12], loss = 13285074.0000
# --> batch [13], loss = 9605006.0000
# --> batch [14], loss = 9725625.0000
# --> batch [15], loss = 4572119.0000
# --> batch [16], loss = 9156116.0000
# --> batch [17], loss = 4837344.5000
# --> batch [18], loss = 8845893.0000
# --> batch [19], loss = 7161902.0000
# --> batch [20], loss = 16261957.0000
# --> batch [21], loss = 11471396.0000
# --> batch [22], loss = 16190714.0000
# Epoch [4800/5000], loss = 16190714.0000
# --> batch [1], loss = 11043293.0000
# --> batch [2], loss = 4508581.5000
# --> batch [3], loss = 7620215.5000
# --> batch [4], loss = 7090330.0000
# --> batch [5], loss = 5597991.0000
# --> batch [6], loss = 11787131.0000
# --> batch [7], loss = 10532811.0000
# --> batch [8], loss = 7795015.5000
# --> batch [9], loss = 6576966.0000
# --> batch [10], loss = 11988650.0000
# --> batch [11], loss = 4858470.0000
# --> batch [12], loss = 15576888.0000
# --> batch [13], loss = 12196108.0000
# --> batch [14], loss = 6419780.0000
# --> batch [15], loss = 6156428.0000
# --> batch [16], loss = 15614790.0000
# --> batch [17], loss = 6765140.5000
# --> batch [18], loss = 6016071.5000
# --> batch [19], loss = 12500275.0000
# --> batch [20], loss = 4697157.0000
# --> batch [21], loss = 7331737.5000
# --> batch [22], loss = 8989580.0000
# --> batch [1], loss = 13168936.0000
# --> batch [2], loss = 5401288.5000
# --> batch [3], loss = 7843426.5000
# --> batch [4], loss = 5719885.0000
# --> batch [5], loss = 11599332.0000
# --> batch [6], loss = 4545238.0000
# --> batch [7], loss = 6091920.5000
# --> batch [8], loss = 4968373.5000
# --> batch [9], loss = 7197358.5000
# --> batch [10], loss = 8644394.0000
# --> batch [11], loss = 7326998.0000
# --> batch [12], loss = 4344455.5000
# --> batch [13], loss = 15091482.0000
# --> batch [14], loss = 6683280.5000
# --> batch [15], loss = 12804398.0000
# --> batch [16], loss = 16293088.0000
# --> batch [17], loss = 7651026.0000
# --> batch [18], loss = 4789060.5000
# --> batch [19], loss = 7669383.5000
# --> batch [20], loss = 4815762.5000
# --> batch [21], loss = 10297705.0000
# --> batch [22], loss = 19195708.0000
# --> batch [1], loss = 18412262.0000
# --> batch [2], loss = 14192165.0000
# --> batch [3], loss = 7359903.5000
# --> batch [4], loss = 4581094.5000
# --> batch [5], loss = 6331977.5000
# --> batch [6], loss = 7343092.0000
# --> batch [7], loss = 12481316.0000
# --> batch [8], loss = 7161186.0000
# --> batch [9], loss = 5217637.0000
# --> batch [10], loss = 7047858.5000
# --> batch [11], loss = 11945937.0000
# --> batch [12], loss = 6996230.0000
# --> batch [13], loss = 9615807.0000
# --> batch [14], loss = 7616990.5000
# --> batch [15], loss = 9684765.0000
# --> batch [16], loss = 8076747.5000
# --> batch [17], loss = 5760283.0000
# --> batch [18], loss = 3890484.5000
# --> batch [19], loss = 8284555.5000
# --> batch [20], loss = 10159351.0000
# --> batch [21], loss = 5923034.0000
# --> batch [22], loss = 4082136.0000
# --> batch [1], loss = 5080703.0000
# --> batch [2], loss = 7870348.0000
# --> batch [3], loss = 7163947.0000
# --> batch [4], loss = 14617944.0000
# --> batch [5], loss = 7482927.5000
# --> batch [6], loss = 3261266.2500
# --> batch [7], loss = 5218869.0000
# --> batch [8], loss = 6906195.0000
# --> batch [9], loss = 4070020.2500
# --> batch [10], loss = 11659195.0000
# --> batch [11], loss = 7122713.5000
# --> batch [12], loss = 7312002.5000
# --> batch [13], loss = 14647260.0000
# --> batch [14], loss = 6899550.0000
# --> batch [15], loss = 7992388.0000
# --> batch [16], loss = 8929693.0000
# --> batch [17], loss = 6589283.0000
# --> batch [18], loss = 18080500.0000
# --> batch [19], loss = 14218664.0000
# --> batch [20], loss = 4610889.5000
# --> batch [21], loss = 10956767.0000
# --> batch [22], loss = 14174074.0000
# --> batch [1], loss = 4769503.0000
# --> batch [2], loss = 5214172.0000
# --> batch [3], loss = 12835286.0000
# --> batch [4], loss = 4245882.5000
# --> batch [5], loss = 4686252.0000
# --> batch [6], loss = 7134638.0000
# --> batch [7], loss = 8612772.0000
# --> batch [8], loss = 9832777.0000
# --> batch [9], loss = 4732212.5000
# --> batch [10], loss = 8902757.0000
# --> batch [11], loss = 6138600.5000
# --> batch [12], loss = 5827520.5000
# --> batch [13], loss = 20178568.0000
# --> batch [14], loss = 12527548.0000
# --> batch [15], loss = 9047537.0000
# --> batch [16], loss = 4447955.0000
# --> batch [17], loss = 10776503.0000
# --> batch [18], loss = 8462123.0000
# --> batch [19], loss = 16855956.0000
# --> batch [20], loss = 11995798.0000
# --> batch [21], loss = 8002460.0000
# --> batch [22], loss = 3770493.5000
# --> batch [1], loss = 15826167.0000
# --> batch [2], loss = 11439846.0000
# --> batch [3], loss = 8994126.0000
# --> batch [4], loss = 8044339.0000
# --> batch [5], loss = 5652347.0000
# --> batch [6], loss = 6449278.5000
# --> batch [7], loss = 5289902.5000
# --> batch [8], loss = 9749166.0000
# --> batch [9], loss = 8085664.0000
# --> batch [10], loss = 11522020.0000
# --> batch [11], loss = 10004411.0000
# --> batch [12], loss = 8179828.5000
# --> batch [13], loss = 6973881.5000
# --> batch [14], loss = 7621085.0000
# --> batch [15], loss = 10252195.0000
# --> batch [16], loss = 10126732.0000
# --> batch [17], loss = 7780776.5000
# --> batch [18], loss = 12871840.0000
# --> batch [19], loss = 4712763.0000
# --> batch [20], loss = 8299762.5000
# --> batch [21], loss = 6025042.0000
# --> batch [22], loss = 10992100.0000
# --> batch [1], loss = 10590400.0000
# --> batch [2], loss = 12785997.0000
# --> batch [3], loss = 11712628.0000
# --> batch [4], loss = 5185024.5000
# --> batch [5], loss = 7262670.0000
# --> batch [6], loss = 13901078.0000
# --> batch [7], loss = 7906509.0000
# --> batch [8], loss = 8394484.0000
# --> batch [9], loss = 8005942.5000
# --> batch [10], loss = 4330839.5000
# --> batch [11], loss = 5988974.5000
# --> batch [12], loss = 4289289.5000
# --> batch [13], loss = 9473676.0000
# --> batch [14], loss = 6289483.5000
# --> batch [15], loss = 10883516.0000
# --> batch [16], loss = 14012417.0000
# --> batch [17], loss = 12622390.0000
# --> batch [18], loss = 6103355.5000
# --> batch [19], loss = 4834361.5000
# --> batch [20], loss = 7806306.5000
# --> batch [21], loss = 8143878.5000
# --> batch [22], loss = 4518135.5000
# --> batch [1], loss = 3477553.5000
# --> batch [2], loss = 5621466.0000
# --> batch [3], loss = 10981711.0000
# --> batch [4], loss = 5746383.5000
# --> batch [5], loss = 10594176.0000
# --> batch [6], loss = 14489130.0000
# --> batch [7], loss = 6112348.0000
# --> batch [8], loss = 13758062.0000
# --> batch [9], loss = 5022648.0000
# --> batch [10], loss = 13123594.0000
# --> batch [11], loss = 5957161.0000
# --> batch [12], loss = 8821517.0000
# --> batch [13], loss = 15481998.0000
# --> batch [14], loss = 8524346.0000
# --> batch [15], loss = 12938002.0000
# --> batch [16], loss = 5064474.0000
# --> batch [17], loss = 5727200.5000
# --> batch [18], loss = 7413431.0000
# --> batch [19], loss = 7572866.5000
# --> batch [20], loss = 7751317.0000
# --> batch [21], loss = 6447092.0000
# --> batch [22], loss = 10215427.0000
# --> batch [1], loss = 9601796.0000
# --> batch [2], loss = 8469110.0000
# --> batch [3], loss = 7390061.0000
# --> batch [4], loss = 7373098.0000
# --> batch [5], loss = 11617377.0000
# --> batch [6], loss = 8342310.5000
# --> batch [7], loss = 12577281.0000
# --> batch [8], loss = 7147148.0000
# --> batch [9], loss = 7783178.0000
# --> batch [10], loss = 8580760.0000
# --> batch [11], loss = 11956032.0000
# --> batch [12], loss = 2985911.0000
# --> batch [13], loss = 13558399.0000
# --> batch [14], loss = 5341484.0000
# --> batch [15], loss = 8611960.0000
# --> batch [16], loss = 14806819.0000
# --> batch [17], loss = 2419047.5000
# --> batch [18], loss = 5315945.5000
# --> batch [19], loss = 10145461.0000
# --> batch [20], loss = 10627010.0000
# --> batch [21], loss = 11820961.0000
# --> batch [22], loss = 6967313.0000
# --> batch [1], loss = 6664061.5000
# --> batch [2], loss = 9716714.0000
# --> batch [3], loss = 6273984.0000
# --> batch [4], loss = 10151802.0000
# --> batch [5], loss = 8433518.0000
# --> batch [6], loss = 6137543.0000
# --> batch [7], loss = 11707028.0000
# --> batch [8], loss = 8249609.5000
# --> batch [9], loss = 8086374.5000
# --> batch [10], loss = 5990061.0000
# --> batch [11], loss = 7483113.0000
# --> batch [12], loss = 10240329.0000
# --> batch [13], loss = 11450510.0000
# --> batch [14], loss = 10269612.0000
# --> batch [15], loss = 8253981.0000
# --> batch [16], loss = 8436350.0000
# --> batch [17], loss = 4792698.0000
# --> batch [18], loss = 11517266.0000
# --> batch [19], loss = 6135706.0000
# --> batch [20], loss = 5067057.0000
# --> batch [21], loss = 3864710.0000
# --> batch [22], loss = 28169398.0000
# --> batch [1], loss = 8662531.0000
# --> batch [2], loss = 5885358.5000
# --> batch [3], loss = 9309929.0000
# --> batch [4], loss = 5206679.5000
# --> batch [5], loss = 4436495.0000
# --> batch [6], loss = 13375272.0000
# --> batch [7], loss = 6889279.5000
# --> batch [8], loss = 8871136.0000
# --> batch [9], loss = 7445294.5000
# --> batch [10], loss = 7643295.5000
# --> batch [11], loss = 7344791.0000
# --> batch [12], loss = 6741818.0000
# --> batch [13], loss = 4837373.5000
# --> batch [14], loss = 5605606.5000
# --> batch [15], loss = 12782034.0000
# --> batch [16], loss = 6542705.5000
# --> batch [17], loss = 10782223.0000
# --> batch [18], loss = 13595753.0000
# --> batch [19], loss = 8303012.5000
# --> batch [20], loss = 12770528.0000
# --> batch [21], loss = 11276465.0000
# --> batch [22], loss = 8329747.0000
# --> batch [1], loss = 9045143.0000
# --> batch [2], loss = 5722542.0000
# --> batch [3], loss = 7090484.5000
# --> batch [4], loss = 9112663.0000
# --> batch [5], loss = 9726621.0000
# --> batch [6], loss = 7522656.0000
# --> batch [7], loss = 8307374.5000
# --> batch [8], loss = 8534242.0000
# --> batch [9], loss = 10121577.0000
# --> batch [10], loss = 11476891.0000
# --> batch [11], loss = 12777411.0000
# --> batch [12], loss = 5362328.5000
# --> batch [13], loss = 10025903.0000
# --> batch [14], loss = 5906685.0000
# --> batch [15], loss = 13181709.0000
# --> batch [16], loss = 6796295.0000
# --> batch [17], loss = 10423944.0000
# --> batch [18], loss = 7180779.5000
# --> batch [19], loss = 7607494.0000
# --> batch [20], loss = 7038452.5000
# --> batch [21], loss = 7712875.5000
# --> batch [22], loss = 4137893.5000
# --> batch [1], loss = 3764070.5000
# --> batch [2], loss = 10616909.0000
# --> batch [3], loss = 10783968.0000
# --> batch [4], loss = 3924602.2500
# --> batch [5], loss = 11436270.0000
# --> batch [6], loss = 10646454.0000
# --> batch [7], loss = 5281802.5000
# --> batch [8], loss = 13261411.0000
# --> batch [9], loss = 9960003.0000
# --> batch [10], loss = 9400576.0000
# --> batch [11], loss = 5976973.0000
# --> batch [12], loss = 6823625.5000
# --> batch [13], loss = 7496184.5000
# --> batch [14], loss = 6578048.5000
# --> batch [15], loss = 13558387.0000
# --> batch [16], loss = 4632398.0000
# --> batch [17], loss = 6210233.0000
# --> batch [18], loss = 12033381.0000
# --> batch [19], loss = 11557935.0000
# --> batch [20], loss = 12543837.0000
# --> batch [21], loss = 5813650.0000
# --> batch [22], loss = 8668099.0000
# --> batch [1], loss = 6096379.0000
# --> batch [2], loss = 6703542.0000
# --> batch [3], loss = 5442441.0000
# --> batch [4], loss = 14419539.0000
# --> batch [5], loss = 15148550.0000
# --> batch [6], loss = 5785076.5000
# --> batch [7], loss = 5760972.0000
# --> batch [8], loss = 3498165.0000
# --> batch [9], loss = 9714200.0000
# --> batch [10], loss = 7811076.0000
# --> batch [11], loss = 10359480.0000
# --> batch [12], loss = 13633129.0000
# --> batch [13], loss = 6090157.0000
# --> batch [14], loss = 8019707.0000
# --> batch [15], loss = 10919160.0000
# --> batch [16], loss = 11559665.0000
# --> batch [17], loss = 6144622.0000
# --> batch [18], loss = 15043871.0000
# --> batch [19], loss = 12777274.0000
# --> batch [20], loss = 5569493.0000
# --> batch [21], loss = 9823023.0000
# --> batch [22], loss = 5844899.0000
# --> batch [1], loss = 5643006.5000
# --> batch [2], loss = 11119619.0000
# --> batch [3], loss = 2323226.0000
# --> batch [4], loss = 8807187.0000
# --> batch [5], loss = 7792357.0000
# --> batch [6], loss = 8069008.5000
# --> batch [7], loss = 8066640.0000
# --> batch [8], loss = 5022823.5000
# --> batch [9], loss = 8206269.0000
# --> batch [10], loss = 13086912.0000
# --> batch [11], loss = 11365050.0000
# --> batch [12], loss = 10255768.0000
# --> batch [13], loss = 8034639.5000
# --> batch [14], loss = 5931938.5000
# --> batch [15], loss = 9723345.0000
# --> batch [16], loss = 10609076.0000
# --> batch [17], loss = 14949619.0000
# --> batch [18], loss = 3507897.0000
# --> batch [19], loss = 8702826.0000
# --> batch [20], loss = 7404156.0000
# --> batch [21], loss = 10438068.0000
# --> batch [22], loss = 22790444.0000
# --> batch [1], loss = 5293351.5000
# --> batch [2], loss = 7908623.5000
# --> batch [3], loss = 9116452.0000
# --> batch [4], loss = 9644271.0000
# --> batch [5], loss = 7861289.0000
# --> batch [6], loss = 5008235.0000
# --> batch [7], loss = 5678542.5000
# --> batch [8], loss = 7280163.0000
# --> batch [9], loss = 9953457.0000
# --> batch [10], loss = 11410519.0000
# --> batch [11], loss = 10389036.0000
# --> batch [12], loss = 10829727.0000
# --> batch [13], loss = 16255791.0000
# --> batch [14], loss = 3897493.0000
# --> batch [15], loss = 7558681.0000
# --> batch [16], loss = 7573280.0000
# --> batch [17], loss = 5301460.0000
# --> batch [18], loss = 17802708.0000
# --> batch [19], loss = 9309240.0000
# --> batch [20], loss = 8658125.0000
# --> batch [21], loss = 10748417.0000
# --> batch [22], loss = 3172781.7500
# --> batch [1], loss = 7330609.5000
# --> batch [2], loss = 11896375.0000
# --> batch [3], loss = 4643106.0000
# --> batch [4], loss = 11068942.0000
# --> batch [5], loss = 8422764.0000
# --> batch [6], loss = 6462132.0000
# --> batch [7], loss = 14041940.0000
# --> batch [8], loss = 10248049.0000
# --> batch [9], loss = 5480375.0000
# --> batch [10], loss = 8706970.0000
# --> batch [11], loss = 7085524.5000
# --> batch [12], loss = 10150844.0000
# --> batch [13], loss = 8925845.0000
# --> batch [14], loss = 14769983.0000
# --> batch [15], loss = 11973572.0000
# --> batch [16], loss = 6647815.0000
# --> batch [17], loss = 19570974.0000
# --> batch [18], loss = 3536936.7500
# --> batch [19], loss = 9686974.0000
# --> batch [20], loss = 8431605.0000
# --> batch [21], loss = 8728556.0000
# --> batch [22], loss = 2903837.5000
# --> batch [1], loss = 7175501.5000
# --> batch [2], loss = 6810327.0000
# --> batch [3], loss = 12626721.0000
# --> batch [4], loss = 5227766.5000
# --> batch [5], loss = 10103919.0000
# --> batch [6], loss = 16055099.0000
# --> batch [7], loss = 10090881.0000
# --> batch [8], loss = 6420916.5000
# --> batch [9], loss = 11692202.0000
# --> batch [10], loss = 5982153.0000
# --> batch [11], loss = 4520274.0000
# --> batch [12], loss = 5876653.0000
# --> batch [13], loss = 4234523.0000
# --> batch [14], loss = 6281033.0000
# --> batch [15], loss = 6051358.0000
# --> batch [16], loss = 10864563.0000
# --> batch [17], loss = 11480973.0000
# --> batch [18], loss = 5392866.0000
# --> batch [19], loss = 8739625.0000
# --> batch [20], loss = 11059293.0000
# --> batch [21], loss = 6695247.5000
# --> batch [22], loss = 19185244.0000
# --> batch [1], loss = 3946601.0000
# --> batch [2], loss = 11242205.0000
# --> batch [3], loss = 6874190.5000
# --> batch [4], loss = 4071571.5000
# --> batch [5], loss = 12033695.0000
# --> batch [6], loss = 5007967.5000
# --> batch [7], loss = 9275962.0000
# --> batch [8], loss = 12731720.0000
# --> batch [9], loss = 5826701.0000
# --> batch [10], loss = 8592657.0000
# --> batch [11], loss = 8164107.5000
# --> batch [12], loss = 7442787.0000
# --> batch [13], loss = 12414806.0000
# --> batch [14], loss = 14402766.0000
# --> batch [15], loss = 8118041.5000
# --> batch [16], loss = 14488731.0000
# --> batch [17], loss = 7512262.0000
# --> batch [18], loss = 8400977.0000
# --> batch [19], loss = 10532687.0000
# --> batch [20], loss = 8412736.0000
# --> batch [21], loss = 4001744.2500
# --> batch [22], loss = 6606301.5000
# --> batch [1], loss = 5737890.5000
# --> batch [2], loss = 5087368.5000
# --> batch [3], loss = 5210410.0000
# --> batch [4], loss = 8792558.0000
# --> batch [5], loss = 15754766.0000
# --> batch [6], loss = 9368397.0000
# --> batch [7], loss = 5863248.5000
# --> batch [8], loss = 5346336.5000
# --> batch [9], loss = 13558779.0000
# --> batch [10], loss = 10578372.0000
# --> batch [11], loss = 7375850.0000
# --> batch [12], loss = 4794355.5000
# --> batch [13], loss = 9165341.0000
# --> batch [14], loss = 8694500.0000
# --> batch [15], loss = 10023590.0000
# --> batch [16], loss = 7022092.0000
# --> batch [17], loss = 12091892.0000
# --> batch [18], loss = 11713469.0000
# --> batch [19], loss = 7294910.0000
# --> batch [20], loss = 7495240.5000
# --> batch [21], loss = 8259851.5000
# --> batch [22], loss = 11650383.0000
# --> batch [1], loss = 10080134.0000
# --> batch [2], loss = 5457588.5000
# --> batch [3], loss = 9264820.0000
# --> batch [4], loss = 7099204.5000
# --> batch [5], loss = 6643401.0000
# --> batch [6], loss = 7900098.5000
# --> batch [7], loss = 7175015.0000
# --> batch [8], loss = 13384608.0000
# --> batch [9], loss = 16108934.0000
# --> batch [10], loss = 15949903.0000
# --> batch [11], loss = 6073666.5000
# --> batch [12], loss = 6308592.5000
# --> batch [13], loss = 4007345.5000
# --> batch [14], loss = 7375205.0000
# --> batch [15], loss = 4966997.0000
# --> batch [16], loss = 7730390.0000
# --> batch [17], loss = 13223954.0000
# --> batch [18], loss = 5169860.0000
# --> batch [19], loss = 9073823.0000
# --> batch [20], loss = 4754741.5000
# --> batch [21], loss = 11409528.0000
# --> batch [22], loss = 10816960.0000
# --> batch [1], loss = 3635765.7500
# --> batch [2], loss = 11226900.0000
# --> batch [3], loss = 11481414.0000
# --> batch [4], loss = 5218320.0000
# --> batch [5], loss = 8045346.5000
# --> batch [6], loss = 8251183.5000
# --> batch [7], loss = 5758342.5000
# --> batch [8], loss = 7770884.0000
# --> batch [9], loss = 10917348.0000
# --> batch [10], loss = 8830409.0000
# --> batch [11], loss = 9250588.0000
# --> batch [12], loss = 11808616.0000
# --> batch [13], loss = 4749120.0000
# --> batch [14], loss = 13106716.0000
# --> batch [15], loss = 8297744.0000
# --> batch [16], loss = 8722810.0000
# --> batch [17], loss = 10473071.0000
# --> batch [18], loss = 6787316.5000
# --> batch [19], loss = 13858103.0000
# --> batch [20], loss = 6353456.5000
# --> batch [21], loss = 10832429.0000
# --> batch [22], loss = 5987474.5000
# --> batch [1], loss = 5379554.0000
# --> batch [2], loss = 5307998.0000
# --> batch [3], loss = 10261956.0000
# --> batch [4], loss = 13089471.0000
# --> batch [5], loss = 4884665.0000
# --> batch [6], loss = 8486764.0000
# --> batch [7], loss = 12012870.0000
# --> batch [8], loss = 7388747.0000
# --> batch [9], loss = 6997940.5000
# --> batch [10], loss = 7771978.0000
# --> batch [11], loss = 9351622.0000
# --> batch [12], loss = 10889455.0000
# --> batch [13], loss = 6958685.0000
# --> batch [14], loss = 8377727.5000
# --> batch [15], loss = 7340827.0000
# --> batch [16], loss = 17388052.0000
# --> batch [17], loss = 16144412.0000
# --> batch [18], loss = 4776864.5000
# --> batch [19], loss = 8263737.0000
# --> batch [20], loss = 7504317.5000
# --> batch [21], loss = 5403636.0000
# --> batch [22], loss = 2714631.5000
# --> batch [1], loss = 6828936.5000
# --> batch [2], loss = 10840827.0000
# --> batch [3], loss = 9896838.0000
# --> batch [4], loss = 6337687.5000
# --> batch [5], loss = 7872394.0000
# --> batch [6], loss = 13109201.0000
# --> batch [7], loss = 10282417.0000
# --> batch [8], loss = 6024952.5000
# --> batch [9], loss = 5747181.0000
# --> batch [10], loss = 11374756.0000
# --> batch [11], loss = 11922409.0000
# --> batch [12], loss = 9637186.0000
# --> batch [13], loss = 9000844.0000
# --> batch [14], loss = 6183463.5000
# --> batch [15], loss = 4706517.0000
# --> batch [16], loss = 2244636.7500
# --> batch [17], loss = 5895903.5000
# --> batch [18], loss = 6600456.5000
# --> batch [19], loss = 10367988.0000
# --> batch [20], loss = 13289446.0000
# --> batch [21], loss = 12750906.0000
# --> batch [22], loss = 11655895.0000
# --> batch [1], loss = 7069561.5000
# --> batch [2], loss = 11880942.0000
# --> batch [3], loss = 6384665.5000
# --> batch [4], loss = 4752887.5000
# --> batch [5], loss = 5682444.0000
# --> batch [6], loss = 14165043.0000
# --> batch [7], loss = 8393320.0000
# --> batch [8], loss = 4664703.0000
# --> batch [9], loss = 9045522.0000
# --> batch [10], loss = 4514308.5000
# --> batch [11], loss = 4508744.5000
# --> batch [12], loss = 8058233.5000
# --> batch [13], loss = 8869778.0000
# --> batch [14], loss = 14724142.0000
# --> batch [15], loss = 15878536.0000
# --> batch [16], loss = 4379540.0000
# --> batch [17], loss = 8157675.5000
# --> batch [18], loss = 9478561.0000
# --> batch [19], loss = 5928670.0000
# --> batch [20], loss = 8362999.0000
# --> batch [21], loss = 8575429.0000
# --> batch [22], loss = 23008180.0000
# --> batch [1], loss = 8946854.0000
# --> batch [2], loss = 8530587.0000
# --> batch [3], loss = 6462096.0000
# --> batch [4], loss = 8201674.0000
# --> batch [5], loss = 3302113.2500
# --> batch [6], loss = 10920718.0000
# --> batch [7], loss = 5993364.0000
# --> batch [8], loss = 5989606.0000
# --> batch [9], loss = 9219265.0000
# --> batch [10], loss = 11569577.0000
# --> batch [11], loss = 7142532.5000
# --> batch [12], loss = 12364004.0000
# --> batch [13], loss = 7149084.0000
# --> batch [14], loss = 12864504.0000
# --> batch [15], loss = 10282703.0000
# --> batch [16], loss = 9922779.0000
# --> batch [17], loss = 5849141.0000
# --> batch [18], loss = 8078269.0000
# --> batch [19], loss = 11074012.0000
# --> batch [20], loss = 7018151.0000
# --> batch [21], loss = 7304483.0000
# --> batch [22], loss = 11725455.0000
# --> batch [1], loss = 12264216.0000
# --> batch [2], loss = 4910080.5000
# --> batch [3], loss = 8192442.0000
# --> batch [4], loss = 5125321.5000
# --> batch [5], loss = 7857418.0000
# --> batch [6], loss = 9885905.0000
# --> batch [7], loss = 7087557.0000
# --> batch [8], loss = 10042717.0000
# --> batch [9], loss = 13344315.0000
# --> batch [10], loss = 9320470.0000
# --> batch [11], loss = 3833165.5000
# --> batch [12], loss = 6446753.5000
# --> batch [13], loss = 10039206.0000
# --> batch [14], loss = 10955813.0000
# --> batch [15], loss = 6922795.0000
# --> batch [16], loss = 7610807.0000
# --> batch [17], loss = 12349142.0000
# --> batch [18], loss = 7562134.5000
# --> batch [19], loss = 7312969.5000
# --> batch [20], loss = 11771315.0000
# --> batch [21], loss = 13422548.0000
# --> batch [22], loss = 5644945.0000
# --> batch [1], loss = 8270384.5000
# --> batch [2], loss = 9115815.0000
# --> batch [3], loss = 10570466.0000
# --> batch [4], loss = 7681538.5000
# --> batch [5], loss = 8740112.0000
# --> batch [6], loss = 9274501.0000
# --> batch [7], loss = 9386048.0000
# --> batch [8], loss = 9038464.0000
# --> batch [9], loss = 13589819.0000
# --> batch [10], loss = 16921314.0000
# --> batch [11], loss = 6849332.5000
# --> batch [12], loss = 5691795.0000
# --> batch [13], loss = 7198128.5000
# --> batch [14], loss = 10845956.0000
# --> batch [15], loss = 6348598.0000
# --> batch [16], loss = 10127364.0000
# --> batch [17], loss = 3841049.0000
# --> batch [18], loss = 6979837.5000
# --> batch [19], loss = 6078642.0000
# --> batch [20], loss = 6448328.5000
# --> batch [21], loss = 4804804.5000
# --> batch [22], loss = 9128944.0000
# --> batch [1], loss = 11534446.0000
# --> batch [2], loss = 13839971.0000
# --> batch [3], loss = 7544096.0000
# --> batch [4], loss = 7527507.0000
# --> batch [5], loss = 6623938.5000
# --> batch [6], loss = 6687375.5000
# --> batch [7], loss = 11774435.0000
# --> batch [8], loss = 5586152.5000
# --> batch [9], loss = 3808804.7500
# --> batch [10], loss = 4713903.0000
# --> batch [11], loss = 7764034.0000
# --> batch [12], loss = 12006848.0000
# --> batch [13], loss = 7941911.5000
# --> batch [14], loss = 6485755.5000
# --> batch [15], loss = 11811291.0000
# --> batch [16], loss = 5697149.5000
# --> batch [17], loss = 11967615.0000
# --> batch [18], loss = 20119258.0000
# --> batch [19], loss = 3142844.2500
# --> batch [20], loss = 2762371.5000
# --> batch [21], loss = 8396709.0000
# --> batch [22], loss = 15360506.0000
# --> batch [1], loss = 9563697.0000
# --> batch [2], loss = 6185598.5000
# --> batch [3], loss = 9950926.0000
# --> batch [4], loss = 8537162.0000
# --> batch [5], loss = 9570061.0000
# --> batch [6], loss = 6765798.0000
# --> batch [7], loss = 13787697.0000
# --> batch [8], loss = 10841905.0000
# --> batch [9], loss = 6172608.5000
# --> batch [10], loss = 8517636.0000
# --> batch [11], loss = 8286555.5000
# --> batch [12], loss = 4645545.0000
# --> batch [13], loss = 7273881.0000
# --> batch [14], loss = 8131856.5000
# --> batch [15], loss = 5392320.5000
# --> batch [16], loss = 15889976.0000
# --> batch [17], loss = 4819218.0000
# --> batch [18], loss = 11676911.0000
# --> batch [19], loss = 6320450.5000
# --> batch [20], loss = 9273526.0000
# --> batch [21], loss = 9166870.0000
# --> batch [22], loss = 6333794.5000
# --> batch [1], loss = 5025437.5000
# --> batch [2], loss = 8821050.0000
# --> batch [3], loss = 12763576.0000
# --> batch [4], loss = 9524371.0000
# --> batch [5], loss = 6732068.0000
# --> batch [6], loss = 9676723.0000
# --> batch [7], loss = 5028701.5000
# --> batch [8], loss = 6081342.0000
# --> batch [9], loss = 9317946.0000
# --> batch [10], loss = 13802316.0000
# --> batch [11], loss = 10918757.0000
# --> batch [12], loss = 11378724.0000
# --> batch [13], loss = 18054692.0000
# --> batch [14], loss = 6684384.0000
# --> batch [15], loss = 5494571.0000
# --> batch [16], loss = 4938510.0000
# --> batch [17], loss = 8283577.5000
# --> batch [18], loss = 6182859.0000
# --> batch [19], loss = 7084155.5000
# --> batch [20], loss = 4306606.5000
# --> batch [21], loss = 13330262.0000
# --> batch [22], loss = 3928003.2500
# --> batch [1], loss = 3583824.0000
# --> batch [2], loss = 17536340.0000
# --> batch [3], loss = 15898280.0000
# --> batch [4], loss = 8706296.0000
# --> batch [5], loss = 10243031.0000
# --> batch [6], loss = 3300398.0000
# --> batch [7], loss = 11088746.0000
# --> batch [8], loss = 5029203.0000
# --> batch [9], loss = 15101891.0000
# --> batch [10], loss = 5715363.0000
# --> batch [11], loss = 5550452.5000
# --> batch [12], loss = 5832522.0000
# --> batch [13], loss = 6106379.0000
# --> batch [14], loss = 5557214.0000
# --> batch [15], loss = 7614290.0000
# --> batch [16], loss = 8407172.0000
# --> batch [17], loss = 9092397.0000
# --> batch [18], loss = 5207161.5000
# --> batch [19], loss = 9085357.0000
# --> batch [20], loss = 12310627.0000
# --> batch [21], loss = 3961464.0000
# --> batch [22], loss = 11293022.0000
# --> batch [1], loss = 20222982.0000
# --> batch [2], loss = 6374762.0000
# --> batch [3], loss = 11403506.0000
# --> batch [4], loss = 7199530.0000
# --> batch [5], loss = 7935489.5000
# --> batch [6], loss = 4515149.0000
# --> batch [7], loss = 8482808.0000
# --> batch [8], loss = 6972077.5000
# --> batch [9], loss = 8355178.0000
# --> batch [10], loss = 6037753.0000
# --> batch [11], loss = 6293942.0000
# --> batch [12], loss = 4006315.0000
# --> batch [13], loss = 6712256.0000
# --> batch [14], loss = 6465896.5000
# --> batch [15], loss = 4150145.5000
# --> batch [16], loss = 8552562.0000
# --> batch [17], loss = 3426966.5000
# --> batch [18], loss = 13366258.0000
# --> batch [19], loss = 14669994.0000
# --> batch [20], loss = 10737620.0000
# --> batch [21], loss = 11701608.0000
# --> batch [22], loss = 23379030.0000
# --> batch [1], loss = 10104067.0000
# --> batch [2], loss = 5956918.0000
# --> batch [3], loss = 5708944.0000
# --> batch [4], loss = 4791137.5000
# --> batch [5], loss = 5503483.5000
# --> batch [6], loss = 10798524.0000
# --> batch [7], loss = 4930995.0000
# --> batch [8], loss = 4388397.5000
# --> batch [9], loss = 10017540.0000
# --> batch [10], loss = 5232034.0000
# --> batch [11], loss = 8625326.0000
# ...
# --> batch [19], loss = 4576172.5000
# --> batch [20], loss = 11020306.0000
# --> batch [21], loss = 2766190.5000
# --> batch [22], loss = 5353691.0000
# --> batch [1], loss = 8702424.0000
# --> batch [2], loss = 8797253.0000
# --> batch [3], loss = 14445395.0000
# --> batch [4], loss = 4464804.0000
# --> batch [5], loss = 8727000.0000
# --> batch [6], loss = 4828239.0000
# --> batch [7], loss = 8314030.0000
# --> batch [8], loss = 3357012.2500
# --> batch [9], loss = 5783328.0000
# --> batch [10], loss = 10387018.0000
# --> batch [11], loss = 4105795.2500
# --> batch [12], loss = 2723466.5000
# --> batch [13], loss = 14061036.0000
# --> batch [14], loss = 4211862.0000
# --> batch [15], loss = 8194636.0000
# --> batch [16], loss = 7453385.0000
# --> batch [17], loss = 14503250.0000
# --> batch [18], loss = 13296782.0000
# --> batch [19], loss = 12221924.0000
# --> batch [20], loss = 6527058.0000
# --> batch [21], loss = 8854140.0000
# --> batch [22], loss = 11690960.0000
# --> batch [1], loss = 6584008.5000
# --> batch [2], loss = 7815197.5000
# --> batch [3], loss = 18180056.0000
# --> batch [4], loss = 6771916.0000
# --> batch [5], loss = 6847534.5000
# --> batch [6], loss = 7427514.0000
# --> batch [7], loss = 3328318.0000
# --> batch [8], loss = 14328028.0000
# --> batch [9], loss = 7673846.5000
# --> batch [10], loss = 10616737.0000
# --> batch [11], loss = 13376154.0000
# --> batch [12], loss = 7548915.0000
# --> batch [13], loss = 9510203.0000
# --> batch [14], loss = 4461335.5000
# --> batch [15], loss = 7510006.0000
# --> batch [16], loss = 5092941.0000
# --> batch [17], loss = 9440590.0000
# --> batch [18], loss = 10259098.0000
# --> batch [19], loss = 7413559.5000
# --> batch [20], loss = 7173726.5000
# --> batch [21], loss = 11899437.0000
# --> batch [22], loss = 6832108.0000
# --> batch [1], loss = 7000216.5000
# --> batch [2], loss = 15959370.0000
# --> batch [3], loss = 10034125.0000
# --> batch [4], loss = 5780483.0000
# --> batch [5], loss = 13713716.0000
# --> batch [6], loss = 6125659.5000
# --> batch [7], loss = 16779698.0000
# --> batch [8], loss = 7247709.5000
# --> batch [9], loss = 4095573.0000
# --> batch [10], loss = 6066136.5000
# --> batch [11], loss = 4606190.5000
# --> batch [12], loss = 7169777.5000
# --> batch [13], loss = 6721975.0000
# --> batch [14], loss = 4246066.5000
# --> batch [15], loss = 8474778.0000
# --> batch [16], loss = 9579532.0000
# --> batch [17], loss = 16321053.0000
# --> batch [18], loss = 10057504.0000
# --> batch [19], loss = 6934397.5000
# --> batch [20], loss = 5229433.5000
# --> batch [21], loss = 6800135.0000
# --> batch [22], loss = 17258676.0000
# --> batch [1], loss = 3929532.2500
# --> batch [2], loss = 16163258.0000
# --> batch [3], loss = 10809128.0000
# --> batch [4], loss = 4340141.0000
# --> batch [5], loss = 10054515.0000
# --> batch [6], loss = 9773100.0000
# --> batch [7], loss = 9267750.0000
# --> batch [8], loss = 6595846.0000
# --> batch [9], loss = 8856621.0000
# --> batch [10], loss = 5501288.5000
# --> batch [11], loss = 6471970.5000
# --> batch [12], loss = 4312577.0000
# --> batch [13], loss = 10014972.0000
# --> batch [14], loss = 7997565.5000
# --> batch [15], loss = 11971981.0000
# --> batch [16], loss = 4622957.5000
# --> batch [17], loss = 4919761.0000
# --> batch [18], loss = 8047707.5000
# --> batch [19], loss = 7691958.0000
# --> batch [20], loss = 10804466.0000
# --> batch [21], loss = 14042926.0000
# --> batch [22], loss = 9520390.0000
# --> batch [1], loss = 6649841.5000
# --> batch [2], loss = 10755980.0000
# --> batch [3], loss = 7297140.5000
# --> batch [4], loss = 5186682.0000
# --> batch [5], loss = 9485588.0000
# --> batch [6], loss = 10138596.0000
# --> batch [7], loss = 7226935.5000
# --> batch [8], loss = 9672993.0000
# --> batch [9], loss = 10363617.0000
# --> batch [10], loss = 4540089.5000
# --> batch [11], loss = 10085901.0000
# --> batch [12], loss = 9533347.0000
# --> batch [13], loss = 12291617.0000
# --> batch [14], loss = 5527547.0000
# --> batch [15], loss = 5610126.5000
# --> batch [16], loss = 10311028.0000
# --> batch [17], loss = 4871285.0000
# --> batch [18], loss = 10300115.0000
# --> batch [19], loss = 5822768.5000
# --> batch [20], loss = 7857566.0000
# --> batch [21], loss = 11385147.0000
# --> batch [22], loss = 11932995.0000
# --> batch [1], loss = 8504394.0000
# --> batch [2], loss = 13592225.0000
# --> batch [3], loss = 8004724.0000
# --> batch [4], loss = 4791432.5000
# --> batch [5], loss = 3865568.2500
# --> batch [6], loss = 8519291.0000
# --> batch [7], loss = 5470002.5000
# --> batch [8], loss = 8870022.0000
# --> batch [9], loss = 5644454.0000
# --> batch [10], loss = 4322795.5000
# --> batch [11], loss = 8511749.0000
# --> batch [12], loss = 4503432.5000
# --> batch [13], loss = 14126829.0000
# --> batch [14], loss = 5330807.0000
# --> batch [15], loss = 5756438.0000
# --> batch [16], loss = 7874002.5000
# --> batch [17], loss = 6617110.0000
# --> batch [18], loss = 15194043.0000
# --> batch [19], loss = 10054315.0000
# --> batch [20], loss = 9379603.0000
# --> batch [21], loss = 13608739.0000
# --> batch [22], loss = 10996410.0000
# --> batch [1], loss = 6248059.0000
# --> batch [2], loss = 12843302.0000
# --> batch [3], loss = 12141421.0000
# --> batch [4], loss = 8140816.5000
# --> batch [5], loss = 16031127.0000
# --> batch [6], loss = 5737974.5000
# --> batch [7], loss = 10360810.0000
# --> batch [8], loss = 6426118.0000
# --> batch [9], loss = 6625929.0000
# --> batch [10], loss = 4171058.2500
# --> batch [11], loss = 7693133.0000
# --> batch [12], loss = 5833990.5000
# --> batch [13], loss = 4901568.0000
# --> batch [14], loss = 7996578.5000
# --> batch [15], loss = 10776741.0000
# --> batch [16], loss = 9779558.0000
# --> batch [17], loss = 14061020.0000
# --> batch [18], loss = 12259087.0000
# --> batch [19], loss = 11239100.0000
# --> batch [20], loss = 6395444.5000
# --> batch [21], loss = 7175584.5000
# --> batch [22], loss = 7448510.5000
# --> batch [1], loss = 9387091.0000
# --> batch [2], loss = 12947250.0000
# --> batch [3], loss = 7202435.0000
# --> batch [4], loss = 11698742.0000
# --> batch [5], loss = 5454015.5000
# --> batch [6], loss = 4283933.0000
# --> batch [7], loss = 11021114.0000
# --> batch [8], loss = 11423791.0000
# --> batch [9], loss = 9261354.0000
# --> batch [10], loss = 12567384.0000
# --> batch [11], loss = 13115423.0000
# --> batch [12], loss = 4846740.0000
# --> batch [13], loss = 12894504.0000
# --> batch [14], loss = 10136781.0000
# --> batch [15], loss = 11740319.0000
# --> batch [16], loss = 7939382.5000
# --> batch [17], loss = 10678372.0000
# --> batch [18], loss = 8213259.0000
# --> batch [19], loss = 7116912.5000
# --> batch [20], loss = 7722629.0000
# --> batch [21], loss = 7083591.5000
# --> batch [22], loss = 5909297.5000
# --> batch [1], loss = 5792468.0000
# --> batch [2], loss = 4553215.5000
# --> batch [3], loss = 9803776.0000
# --> batch [4], loss = 11255747.0000
# --> batch [5], loss = 7683335.0000
# --> batch [6], loss = 12547258.0000
# --> batch [7], loss = 10913612.0000
# --> batch [8], loss = 7523635.0000
# --> batch [9], loss = 5552686.5000
# --> batch [10], loss = 6088692.0000
# --> batch [11], loss = 14068312.0000
# --> batch [12], loss = 6085003.5000
# --> batch [13], loss = 7439229.0000
# --> batch [14], loss = 8778153.0000
# --> batch [15], loss = 5569451.0000
# --> batch [16], loss = 14628428.0000
# --> batch [17], loss = 11801669.0000
# --> batch [18], loss = 5642589.0000
# --> batch [19], loss = 8784320.0000
# --> batch [20], loss = 8980053.0000
# --> batch [21], loss = 5715737.5000
# --> batch [22], loss = 4351562.5000
# --> batch [1], loss = 10417509.0000
# --> batch [2], loss = 19033830.0000
# --> batch [3], loss = 18086326.0000
# --> batch [4], loss = 8485676.0000
# --> batch [5], loss = 2434335.7500
# --> batch [6], loss = 5115169.5000
# --> batch [7], loss = 4444595.0000
# --> batch [8], loss = 14782592.0000
# --> batch [9], loss = 7057357.5000
# --> batch [10], loss = 5774834.5000
# --> batch [11], loss = 6536849.5000
# --> batch [12], loss = 7379783.0000
# --> batch [13], loss = 7331623.5000
# --> batch [14], loss = 8884772.0000
# --> batch [15], loss = 7788464.0000
# --> batch [16], loss = 6191636.0000
# --> batch [17], loss = 5979643.0000
# --> batch [18], loss = 6961700.5000
# --> batch [19], loss = 5770814.5000
# --> batch [20], loss = 11449770.0000
# --> batch [21], loss = 4397725.0000
# --> batch [22], loss = 8276186.5000
# --> batch [1], loss = 7497188.5000
# --> batch [2], loss = 10695917.0000
# --> batch [3], loss = 11665107.0000
# --> batch [4], loss = 3816020.5000
# --> batch [5], loss = 9597223.0000
# --> batch [6], loss = 6754389.0000
# --> batch [7], loss = 5984729.0000
# --> batch [8], loss = 5369483.0000
# --> batch [9], loss = 7681035.5000
# --> batch [10], loss = 12536371.0000
# --> batch [11], loss = 15383680.0000
# --> batch [12], loss = 10084001.0000
# --> batch [13], loss = 10359964.0000
# --> batch [14], loss = 10949847.0000
# --> batch [15], loss = 8848855.0000
# --> batch [16], loss = 6911456.5000
# --> batch [17], loss = 4848198.0000
# --> batch [18], loss = 4286521.5000
# --> batch [19], loss = 5745727.5000
# --> batch [20], loss = 6218594.5000
# --> batch [21], loss = 12219119.0000
# --> batch [22], loss = 2107782.2500
# --> batch [1], loss = 9144234.0000
# --> batch [2], loss = 4489648.5000
# --> batch [3], loss = 5550325.0000
# --> batch [4], loss = 10626403.0000
# --> batch [5], loss = 6467943.0000
# --> batch [6], loss = 10919473.0000
# --> batch [7], loss = 13302362.0000
# --> batch [8], loss = 11312127.0000
# --> batch [9], loss = 5775202.0000
# --> batch [10], loss = 5032990.5000
# --> batch [11], loss = 5152201.5000
# --> batch [12], loss = 13084879.0000
# --> batch [13], loss = 9203681.0000
# --> batch [14], loss = 8826684.0000
# --> batch [15], loss = 5880493.0000
# --> batch [16], loss = 7291034.0000
# --> batch [17], loss = 5383878.5000
# --> batch [18], loss = 7118571.0000
# --> batch [19], loss = 9472660.0000
# --> batch [20], loss = 10409209.0000
# --> batch [21], loss = 8326788.0000
# --> batch [22], loss = 12395798.0000
# --> batch [1], loss = 4668616.0000
# --> batch [2], loss = 8735724.0000
# --> batch [3], loss = 6887539.0000
# --> batch [4], loss = 14452417.0000
# --> batch [5], loss = 14360195.0000
# --> batch [6], loss = 7163383.0000
# --> batch [7], loss = 4361466.0000
# --> batch [8], loss = 12377599.0000
# --> batch [9], loss = 6524537.5000
# --> batch [10], loss = 7315771.0000
# --> batch [11], loss = 10861444.0000
# --> batch [12], loss = 10330493.0000
# --> batch [13], loss = 9880044.0000
# --> batch [14], loss = 8432738.0000
# --> batch [15], loss = 5300934.5000
# --> batch [16], loss = 3483701.0000
# --> batch [17], loss = 7446818.0000
# --> batch [18], loss = 11743887.0000
# --> batch [19], loss = 5219822.0000
# --> batch [20], loss = 6629795.0000
# --> batch [21], loss = 9586742.0000
# --> batch [22], loss = 7874561.5000
# --> batch [1], loss = 9976156.0000
# --> batch [2], loss = 6247367.0000
# --> batch [3], loss = 4557943.5000
# --> batch [4], loss = 3663433.0000
# --> batch [5], loss = 13521531.0000
# --> batch [6], loss = 13681119.0000
# --> batch [7], loss = 11742423.0000
# --> batch [8], loss = 9946714.0000
# --> batch [9], loss = 10361923.0000
# --> batch [10], loss = 2706432.0000
# --> batch [11], loss = 12008000.0000
# --> batch [12], loss = 5146702.0000
# --> batch [13], loss = 6622912.5000
# --> batch [14], loss = 9299260.0000
# --> batch [15], loss = 12910536.0000
# --> batch [16], loss = 7260381.0000
# --> batch [17], loss = 12314394.0000
# --> batch [18], loss = 5654614.5000
# --> batch [19], loss = 7014334.5000
# --> batch [20], loss = 5189089.5000
# --> batch [21], loss = 10255005.0000
# --> batch [22], loss = 4776853.0000
# --> batch [1], loss = 9163220.0000
# --> batch [2], loss = 4385767.5000
# --> batch [3], loss = 6098998.5000
# --> batch [4], loss = 6566391.5000
# --> batch [5], loss = 9444422.0000
# --> batch [6], loss = 3132954.5000
# --> batch [7], loss = 2859562.5000
# --> batch [8], loss = 15247148.0000
# --> batch [9], loss = 10400434.0000
# --> batch [10], loss = 11369450.0000
# --> batch [11], loss = 9775336.0000
# --> batch [12], loss = 8263399.5000
# --> batch [13], loss = 6175436.0000
# --> batch [14], loss = 9478619.0000
# --> batch [15], loss = 8085275.0000
# --> batch [16], loss = 6687745.5000
# --> batch [17], loss = 6329150.5000
# --> batch [18], loss = 5985714.0000
# --> batch [19], loss = 18539180.0000
# --> batch [20], loss = 5896210.5000
# --> batch [21], loss = 15748093.0000
# --> batch [22], loss = 5831760.0000
# --> batch [1], loss = 7849582.0000
# --> batch [2], loss = 8578321.0000
# --> batch [3], loss = 7157564.0000
# --> batch [4], loss = 13613059.0000
# --> batch [5], loss = 9136061.0000
# --> batch [6], loss = 9148524.0000
# --> batch [7], loss = 4142203.2500
# --> batch [8], loss = 7752307.0000
# --> batch [9], loss = 8224048.5000
# --> batch [10], loss = 11029697.0000
# --> batch [11], loss = 10758226.0000
# --> batch [12], loss = 5515221.0000
# --> batch [13], loss = 10266624.0000
# --> batch [14], loss = 8197364.0000
# --> batch [15], loss = 6643197.5000
# --> batch [16], loss = 8509139.0000
# --> batch [17], loss = 6725059.0000
# --> batch [18], loss = 9561343.0000
# --> batch [19], loss = 5979876.0000
# --> batch [20], loss = 20066444.0000
# --> batch [21], loss = 2982934.5000
# --> batch [22], loss = 3865583.5000
# --> batch [1], loss = 10954049.0000
# --> batch [2], loss = 7381192.5000
# --> batch [3], loss = 6107503.5000
# --> batch [4], loss = 8591640.0000
# --> batch [5], loss = 10645017.0000
# --> batch [6], loss = 7644855.0000
# --> batch [7], loss = 16766204.0000
# --> batch [8], loss = 8964189.0000
# --> batch [9], loss = 7155312.5000
# --> batch [10], loss = 7812431.5000
# --> batch [11], loss = 3768647.2500
# --> batch [12], loss = 12038979.0000
# --> batch [13], loss = 4159435.7500
# --> batch [14], loss = 13180557.0000
# --> batch [15], loss = 4956404.0000
# --> batch [16], loss = 8451124.0000
# --> batch [17], loss = 9551181.0000
# --> batch [18], loss = 10293871.0000
# --> batch [19], loss = 10531933.0000
# --> batch [20], loss = 5064278.0000
# --> batch [21], loss = 6735995.0000
# --> batch [22], loss = 2471573.5000
# --> batch [1], loss = 3134867.0000
# --> batch [2], loss = 8944355.0000
# --> batch [3], loss = 10803729.0000
# --> batch [4], loss = 8453783.0000
# --> batch [5], loss = 9849768.0000
# --> batch [6], loss = 9454269.0000
# --> batch [7], loss = 11857139.0000
# --> batch [8], loss = 4241564.0000
# --> batch [9], loss = 6450930.5000
# --> batch [10], loss = 3380169.0000
# --> batch [11], loss = 13313366.0000
# --> batch [12], loss = 4959984.0000
# --> batch [13], loss = 12014362.0000
# --> batch [14], loss = 6516043.0000
# --> batch [15], loss = 6467885.0000
# --> batch [16], loss = 8682639.0000
# --> batch [17], loss = 8414431.0000
# --> batch [18], loss = 16663037.0000
# --> batch [19], loss = 3039813.0000
# --> batch [20], loss = 14965050.0000
# --> batch [21], loss = 9444447.0000
# --> batch [22], loss = 2721935.5000
# --> batch [1], loss = 7515657.5000
# --> batch [2], loss = 7255237.0000
# --> batch [3], loss = 12114769.0000
# --> batch [4], loss = 8015219.0000
# --> batch [5], loss = 11737999.0000
# --> batch [6], loss = 5461987.0000
# --> batch [7], loss = 7837773.5000
# --> batch [8], loss = 6493876.0000
# --> batch [9], loss = 6424210.5000
# --> batch [10], loss = 8979512.0000
# --> batch [11], loss = 5594791.5000
# --> batch [12], loss = 8999904.0000
# --> batch [13], loss = 7639936.0000
# --> batch [14], loss = 8615375.0000
# --> batch [15], loss = 6070301.5000
# --> batch [16], loss = 13992340.0000
# --> batch [17], loss = 9340280.0000
# --> batch [18], loss = 11624691.0000
# --> batch [19], loss = 12222275.0000
# --> batch [20], loss = 8573491.0000
# --> batch [21], loss = 8223958.5000
# --> batch [22], loss = 3607939.2500
# --> batch [1], loss = 4907402.0000
# --> batch [2], loss = 8757294.0000
# --> batch [3], loss = 7595030.5000
# --> batch [4], loss = 12068453.0000
# --> batch [5], loss = 7711230.5000
# --> batch [6], loss = 8426515.0000
# --> batch [7], loss = 6516310.5000
# --> batch [8], loss = 8090092.0000
# --> batch [9], loss = 7898697.0000
# --> batch [10], loss = 6115207.0000
# --> batch [11], loss = 5747572.0000
# --> batch [12], loss = 3341147.5000
# --> batch [13], loss = 11594989.0000
# --> batch [14], loss = 4091696.2500
# --> batch [15], loss = 12161944.0000
# --> batch [16], loss = 11604287.0000
# --> batch [17], loss = 14438555.0000
# --> batch [18], loss = 4431563.0000
# --> batch [19], loss = 10193998.0000
# --> batch [20], loss = 10659040.0000
# --> batch [21], loss = 14101486.0000
# --> batch [22], loss = 22109230.0000
# Epoch [5000/5000], loss = 22109230.0000

# %% [markdown]
# # Validate the model

# %%
model.eval() # Evaluate mode
y_predic = model(X_test_tensor).detach().numpy()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test_tensor.numpy(), y_predic)
rmse = mse ** 0.5
mae = mean_absolute_error(y_test_tensor.numpy(), y_predic)
r2 = r2_score(y_test_tensor.numpy(), y_predic)

print(f'Mean Square Error: {mse:.2f}')
print(f'Root Mean Square Error: {rmse:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
print(f'R2 Score: {r2:.2f}')
# Out:
# Mean Square Error: 33413968.00
# Root Mean Square Error: 5780.48
# Mean Absolute Error: 3833.89
# R2 Score: 0.78

# %% [markdown]
# # Predict the charges

# %%
def predict_one(age, sex, bmi, children, smoker, region):
  # Create a dataframe
  predict_df = pd.DataFrame([[age, sex, bmi, children, smoker, region]], columns=['age', 'sex', 'bmi', 'children', 'smoker', 'region'])

  # Label encode for categorical using above encoder
  for col in ['sex', 'smoker', 'region']:
    le = label_encoder[col]
    predict_df[col] = le.transform(predict_df[col])

  # Normalize the value
  predict_df = scaler.transform(predict_df)

  # convert dataframe to tensor
  x_tensor = torch.tensor(predict_df, dtype=torch.float32)

  # run model
  model.eval()
  charges = model(x_tensor).item()
  return charges

# %%
one = predict_one(19, 'female', 27.9, 0, 'yes', 'southwest')

print(f'Predicted value: {one:.2f}')
# Out:
# Predicted value: 17583.75
